# %%
# %config InlineBackend.figure_format = "retina"

# %%
import matplotlib.pyplot as plt
import math

import numpy as np
import pandas as pd

import ROOT, uproot

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import feature_selection
from sklearn.model_selection import StratifiedKFold

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# Out:
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# Welcome to JupyROOT 6.18/04

# %%
def upsample(sample, scale):
    '''
    This function takes the sample and concatantes the same sample n times.
    '''
    if scale > 0:
        sample = np.vstack([sample]*scale)
    else:
        sample = sample
    return sample

# %%
input_branches = ['br_njets', 'br_nbjets', 'br_scalar_ht',
       'br_jet_pt_1', 'br_jet_pt_2', 'br_jet_pt_3', 'br_jet_pt_4', 'br_met',
       'br_met_phi', 'br_sphericity', 'br_aplanarity', 'br_fox_wolfram_1',
       'br_fox_wolfram_2', 'br_fox_wolfram_3', 'br_fox_wolfram_4']

df_signal = uproot.open("/mnt/harddisk4/scratch/ttbar_no_dtG_flat.root")["outtree"].pandas.df(input_branches)
df_dyjets = uproot.open("/mnt/harddisk4/scratch/dyjets_flat_30M.root")["outtree"].pandas.df(input_branches)
df_wjets  = uproot.open("/mnt/harddisk4/scratch/wjets_flat_60M.root")["outtree"].pandas.df(input_branches)
df_single_top  = uproot.open("/mnt/harddisk4/scratch/single_top_merged_flat.root")["outtree"].pandas.df(input_branches)
print(df_signal.keys())
#print("n_signal:", len(df_signal), "n_dyjets:", len(df_dyjets), "n_wjets:", len(df_wjets), "n_single_top", len(df_single_top))
# Out:
# Index(['br_njets', 'br_nbjets', 'br_scalar_ht', 'br_jet_pt_1', 'br_jet_pt_2',
#        'br_jet_pt_3', 'br_jet_pt_4', 'br_met', 'br_met_phi', 'br_sphericity',
#        'br_aplanarity', 'br_fox_wolfram_1', 'br_fox_wolfram_2',
#        'br_fox_wolfram_3', 'br_fox_wolfram_4'],
#       dtype='object')

# %%
x_signal = df_signal.values
y_signal = np.full(len(x_signal) , 1)
print("number of signal events:%d" % (len(x_signal)))

x_dyjets = df_dyjets.values
x_wjets  = df_wjets.values
x_single_top  = df_single_top.values

x_wjets  = upsample(x_wjets,  int((len(x_signal)/len(x_wjets))))
x_dyjets = upsample(x_dyjets, int((len(x_signal)/len(x_dyjets))))
idx_max = int(0.33*len(x_signal))
x_bkg    = np.concatenate((x_dyjets[0:idx_max], x_wjets[0:idx_max], x_single_top[0:idx_max]), axis=0)
#x_bkg    = np.concatenate((x_dyjets[0:idx_max], x_single_top[0:idx_max]), axis=0)

#x_bkg    = x_single_top[0:idx_max]
y_bkg    = np.full(len(x_bkg) , 0)
print(idx_max)
# Out:
# number of signal events:135342
# 44662

# %%
x_sig_train, x_sig_test, y_sig_train, y_sig_test = train_test_split(x_signal, y_signal, test_size=0.2, random_state=20)
x_bkg_train, x_bkg_test, y_bkg_train, y_bkg_test = train_test_split(x_bkg, y_bkg, test_size=0.5, random_state=20)

x_train = np.concatenate((x_sig_train, x_bkg_train), axis=0)
y_train = np.concatenate((y_sig_train, y_bkg_train), axis=0)

x_test = np.concatenate((x_sig_test, x_bkg_test), axis=0)
y_test = np.concatenate((y_sig_test, y_bkg_test), axis=0)
                                  
scaler  = preprocessing.StandardScaler().fit(np.concatenate((x_train, x_test), axis=0))
x_train = scaler.transform(x_train)
x_test  = scaler.transform(x_test)

# %%
print("training for", len(x_train), "events;", "testing for",  len(x_test), "events")
# Out:
# training for 175266 events; testing for 94062 events

# %%
model = LinearDiscriminantAnalysis()
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.5698050222193872

# %%
from sklearn.metrics import accuracy_score
accuracy_score(model.predict(x_test), y_test)
# Out:
# 0.5698050222193872

# %%
x_signal_trans = scaler.transform(x_signal)

# %%
output_array1 = model.predict_proba(scaler.transform(x_sig_train))[:,1]
output_array2 = model.predict_proba(scaler.transform(x_bkg_train))[:,1]

output_array3 = model.predict_proba(scaler.transform(x_sig_test))[:,1]
output_array4 = model.predict_proba(scaler.transform(x_bkg_test))[:,1]

# %%
#print(model.evaluate(x_train, y_train))
#print(model.evaluate(x_test, y_test))
#print(model.evaluate(scaler.transform(x_signal), y_signal))
#print(model.evaluate(scaler.transform(x_bkg), y_bkg))

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots()
n_bins = 20

y, bins, patches = ax.hist(output_array2, bins=n_bins, density=True, color='blue', alpha=0.5, label='background (training)')
y, bins, patches = ax.hist(output_array4, bins=n_bins, density=True, color='blue', alpha=0.0)
bin_centers = [0.5*(bins[i]+bins[i+1]) for i in range(len(bins)-1)]
plt.scatter(bin_centers, y, marker='o', c='blue', s=40, alpha=1,  label='background (validation)')

y, bins, patches = ax.hist(output_array1, bins=n_bins, density=True, color='red', alpha=0.5, label='signal (training)')
y, bins, patches = ax.hist(output_array3, bins=n_bins, density=True, color='red', alpha=0.0)
bin_centers = [0.5*(bins[i]+bins[i+1]) for i in range(len(bins)-1)]
plt.scatter(0.5*(bins[1:] + bins[:-1]), y, marker='o', c='red', s=40, alpha=1, label='signal (validation)')

ax.set_xlabel('model output')
ax.set_ylabel('Probability density')
ax.set_title("Fisher's Linear Discriminant Analysis")
ax.legend()
#ax.set_yscale('log')

# %%
def get_signal_significance(xsec_sig, xsec_bkg, lumi, output_sig, output_bkg, thresholds):
    
    significance = []
    
    for threshold in thresholds:
        
        n_sig_expected = xsec_sig * lumi
        n_bkg_expected = xsec_bkg * lumi
        
        n_sig_pred_correct = len(output_sig[output_sig>threshold])
        n_sig_pred_wrong   = len(output_sig[output_sig<threshold])
        n_bkg_pred_correct = len(output_bkg[output_bkg<threshold])
        n_bkg_pred_wrong   = len(output_bkg[output_bkg>threshold])
        
        eff_sig = n_sig_pred_correct/len(output_sig)
        eff_bkg = n_bkg_pred_correct/len(output_bkg)
        
        n_sig = n_sig_expected * eff_sig
        n_bkg = n_bkg_expected * (1-eff_bkg)
        
        n_observed = n_sig + n_bkg
        
        if n_bkg > 0:
            sig = math.sqrt(2*n_observed*math.log(1+n_sig/n_bkg)-2*n_sig)
            #sig = n_sig/math.sqrt(n_sig+n_bkg)
        else:
            sig = 0
        
        print("threshold:", "{:.3f}".format(threshold), "\n"
              "eff_sig:", "{:.3f}".format(eff_sig),
              "eff_bkg:", "{:.3f}".format(eff_bkg),
              "n_sig:", "{:.0f}".format(n_sig), 
              "n_bkg:", "{:.0f}".format(n_bkg),
              "n_observed:", "{:.0f}".format(n_observed), "\n",
              "significance:", "{:.3f}".format(sig), "\n\n")
        
        significance.append(sig)    
        
    return thresholds, np.array(significance)

# %%
thresholds , significance = get_signal_significance(1, 100, 50000, output_array1, 
                                                    output_array2, np.arange(0.1, 1-1e-3, 1e-2))
# Out:
# threshold: 0.100
# eff_sig: 1.000 eff_bkg: 0.004 n_sig: 49984 n_bkg: 4980595 n_observed: 5030579
#  significance: 22.360
#
#
# threshold: 0.110
# eff_sig: 1.000 eff_bkg: 0.007 n_sig: 49977 n_bkg: 4964847 n_observed: 5014824
#  significance: 22.392
#
#
# threshold: 0.120
# eff_sig: 0.999 eff_bkg: 0.008 n_sig: 49971 n_bkg: 4962384 n_observed: 5012355
#  significance: 22.395
#
#
# threshold: 0.130
# eff_sig: 0.999 eff_bkg: 0.008 n_sig: 49961 n_bkg: 4960220 n_observed: 5010181
#  significance: 22.395
#
#
# threshold: 0.140
# eff_sig: 0.999 eff_bkg: 0.009 n_sig: 49949 n_bkg: 4955518 n_observed: 5005466
#  significance: 22.400
#
#
# threshold: 0.150
# eff_sig: 0.999 eff_bkg: 0.010 n_sig: 49940 n_bkg: 4952159 n_observed: 5002099
#  significance: 22.404
#
#
# threshold: 0.160
# eff_sig: 0.998 eff_bkg: 0.012 n_sig: 49924 n_bkg: 4939844 n_observed: 4989768
#  significance: 22.424
#
#
# threshold: 0.170
# eff_sig: 0.998 eff_bkg: 0.014 n_sig: 49910 n_bkg: 4930142 n_observed: 4980052
#  significance: 22.440
#
#
# threshold: 0.180
# eff_sig: 0.998 eff_bkg: 0.017 n_sig: 49890 n_bkg: 4913946 n_observed: 4963836
#  significance: 22.468
#
#
# threshold: 0.190
# eff_sig: 0.997 eff_bkg: 0.021 n_sig: 49873 n_bkg: 4896706 n_observed: 4946578
#  significance: 22.500
#
#
# threshold: 0.200
# eff_sig: 0.997 eff_bkg: 0.030 n_sig: 49845 n_bkg: 4851776 n_observed: 4901621
#  significance: 22.591
#
#
# threshold: 0.210
# eff_sig: 0.996 eff_bkg: 0.034 n_sig: 49817 n_bkg: 4830654 n_observed: 4880471
#  significance: 22.627
#
#
# threshold: 0.220
# eff_sig: 0.996 eff_bkg: 0.037 n_sig: 49777 n_bkg: 4814458 n_observed: 4864236
#  significance: 22.647
#
#
# threshold: 0.230
# eff_sig: 0.995 eff_bkg: 0.041 n_sig: 49733 n_bkg: 4792889 n_observed: 4842621
#  significance: 22.677
#
#
# threshold: 0.240
# eff_sig: 0.994 eff_bkg: 0.048 n_sig: 49680 n_bkg: 4760273 n_observed: 4809953
#  significance: 22.731
#
#
# threshold: 0.250
# eff_sig: 0.992 eff_bkg: 0.058 n_sig: 49621 n_bkg: 4711462 n_observed: 4761083
#  significance: 22.821
#
#
# threshold: 0.260
# eff_sig: 0.991 eff_bkg: 0.068 n_sig: 49551 n_bkg: 4661532 n_observed: 4711083
#  significance: 22.910
#
#
# threshold: 0.270
# eff_sig: 0.989 eff_bkg: 0.077 n_sig: 49470 n_bkg: 4615258 n_observed: 4664728
#  significance: 22.986
#
#
# threshold: 0.280
# eff_sig: 0.988 eff_bkg: 0.084 n_sig: 49385 n_bkg: 4579434 n_observed: 4628819
#  significance: 23.036
#
#
# threshold: 0.290
# eff_sig: 0.985 eff_bkg: 0.098 n_sig: 49274 n_bkg: 4511964 n_observed: 4561238
#  significance: 23.155
#
#
# threshold: 0.300
# eff_sig: 0.983 eff_bkg: 0.112 n_sig: 49167 n_bkg: 4437702 n_observed: 4486869
#  significance: 23.297
#
#
# threshold: 0.310
# eff_sig: 0.981 eff_bkg: 0.127 n_sig: 49043 n_bkg: 4367322 n_observed: 4416365
#  significance: 23.424
#
#
# threshold: 0.320
# eff_sig: 0.978 eff_bkg: 0.143 n_sig: 48902 n_bkg: 4285373 n_observed: 4334275
#  significance: 23.578
#
#
# threshold: 0.330
# eff_sig: 0.975 eff_bkg: 0.152 n_sig: 48742 n_bkg: 4238726 n_observed: 4287469
#  significance: 23.630
#
#
# threshold: 0.340
# eff_sig: 0.971 eff_bkg: 0.168 n_sig: 48554 n_bkg: 4157897 n_observed: 4206451
#  significance: 23.766
#
#
# threshold: 0.350
# eff_sig: 0.967 eff_bkg: 0.182 n_sig: 48335 n_bkg: 4090651 n_observed: 4138986
#  significance: 23.851
#
#
# threshold: 0.360
# eff_sig: 0.962 eff_bkg: 0.196 n_sig: 48115 n_bkg: 4020271 n_observed: 4068386
#  significance: 23.949
#
#
# threshold: 0.370
# eff_sig: 0.958 eff_bkg: 0.224 n_sig: 47878 n_bkg: 3881226 n_observed: 3929104
#  significance: 24.253
#
#
# threshold: 0.380
# eff_sig: 0.952 eff_bkg: 0.247 n_sig: 47606 n_bkg: 3764498 n_observed: 3812104
#  significance: 24.485
#
#
# threshold: 0.390
# eff_sig: 0.946 eff_bkg: 0.265 n_sig: 47323 n_bkg: 3676205 n_observed: 3723528
#  significance: 24.629
#
#
# threshold: 0.400
# eff_sig: 0.940 eff_bkg: 0.280 n_sig: 47013 n_bkg: 3598958 n_observed: 3645971
#  significance: 24.728
#
#
# threshold: 0.410
# eff_sig: 0.933 eff_bkg: 0.294 n_sig: 46665 n_bkg: 3527607 n_observed: 3574273
#  significance: 24.791
#
#
# threshold: 0.420
# eff_sig: 0.926 eff_bkg: 0.307 n_sig: 46310 n_bkg: 3463869 n_observed: 3510180
#  significance: 24.827
#
#
# threshold: 0.430
# eff_sig: 0.918 eff_bkg: 0.322 n_sig: 45913 n_bkg: 3390578 n_observed: 3436491
#  significance: 24.878
#
#
# threshold: 0.440
# eff_sig: 0.910 eff_bkg: 0.343 n_sig: 45484 n_bkg: 3284597 n_observed: 3330081
#  significance: 25.039
#
#
# threshold: 0.450
# eff_sig: 0.901 eff_bkg: 0.361 n_sig: 45058 n_bkg: 3195035 n_observed: 3240094
#  significance: 25.149
#
#
# threshold: 0.460
# eff_sig: 0.892 eff_bkg: 0.384 n_sig: 44595 n_bkg: 3078680 n_observed: 3123275
#  significance: 25.355
#
#
# threshold: 0.470
# eff_sig: 0.881 eff_bkg: 0.400 n_sig: 44066 n_bkg: 2999269 n_observed: 3043335
#  significance: 25.383
#
#
# threshold: 0.480
# eff_sig: 0.870 eff_bkg: 0.423 n_sig: 43516 n_bkg: 2883062 n_observed: 2926579
#  significance: 25.565
#
#
# threshold: 0.490
# eff_sig: 0.859 eff_bkg: 0.441 n_sig: 42939 n_bkg: 2792829 n_observed: 2835768
#  significance: 25.628
#
#
# threshold: 0.500
# eff_sig: 0.847 eff_bkg: 0.461 n_sig: 42340 n_bkg: 2696998 n_observed: 2739338
#  significance: 25.714
#
#
# threshold: 0.510
# eff_sig: 0.834 eff_bkg: 0.485 n_sig: 41699 n_bkg: 2573926 n_observed: 2615625
#  significance: 25.922
#
#
# threshold: 0.520
# eff_sig: 0.821 eff_bkg: 0.504 n_sig: 41028 n_bkg: 2478990 n_observed: 2520018
#  significance: 25.987
#
#
# threshold: 0.530
# eff_sig: 0.806 eff_bkg: 0.520 n_sig: 40319 n_bkg: 2400848 n_observed: 2441167
#  significance: 25.949
#
#
# threshold: 0.540
# eff_sig: 0.792 eff_bkg: 0.541 n_sig: 39578 n_bkg: 2295613 n_observed: 2335191
#  significance: 26.047
#
#
# threshold: 0.550
# eff_sig: 0.776 eff_bkg: 0.566 n_sig: 38822 n_bkg: 2167689 n_observed: 2206511
#  significance: 26.290
#
#
# threshold: 0.560
# eff_sig: 0.761 eff_bkg: 0.588 n_sig: 38025 n_bkg: 2059618 n_observed: 2097643
#  significance: 26.415
#
#
# threshold: 0.570
# eff_sig: 0.745 eff_bkg: 0.603 n_sig: 37234 n_bkg: 1984237 n_observed: 2021471
#  significance: 26.351
#
#
# threshold: 0.580
# eff_sig: 0.728 eff_bkg: 0.617 n_sig: 36391 n_bkg: 1916096 n_observed: 1952487
#  significance: 26.207
#
#
# threshold: 0.590
# eff_sig: 0.711 eff_bkg: 0.634 n_sig: 35526 n_bkg: 1832430 n_observed: 1867957
#  significance: 26.160
#
#
# threshold: 0.600
# eff_sig: 0.692 eff_bkg: 0.650 n_sig: 34616 n_bkg: 1749959 n_observed: 1784575
#  significance: 26.082
#
#
# threshold: 0.610
# eff_sig: 0.674 eff_bkg: 0.666 n_sig: 33677 n_bkg: 1668309 n_observed: 1701986
#  significance: 25.986
#
#
# threshold: 0.620
# eff_sig: 0.654 eff_bkg: 0.692 n_sig: 32710 n_bkg: 1541131 n_observed: 1573842
#  significance: 26.257
#
#
# threshold: 0.630
# eff_sig: 0.635 eff_bkg: 0.714 n_sig: 31734 n_bkg: 1430672 n_observed: 1462406
#  significance: 26.434
#
#
# threshold: 0.640
# eff_sig: 0.615 eff_bkg: 0.732 n_sig: 30733 n_bkg: 1342081 n_observed: 1372813
#  significance: 26.428
#
#
# threshold: 0.650
# eff_sig: 0.593 eff_bkg: 0.748 n_sig: 29675 n_bkg: 1258564 n_observed: 1288239
#  significance: 26.349
#
#
# threshold: 0.660
# eff_sig: 0.573 eff_bkg: 0.760 n_sig: 28640 n_bkg: 1197886 n_observed: 1226526
#  significance: 26.065
#
#
# threshold: 0.670
# eff_sig: 0.551 eff_bkg: 0.771 n_sig: 27541 n_bkg: 1145120 n_observed: 1172661
#  significance: 25.635
#
#
# threshold: 0.680
# eff_sig: 0.529 eff_bkg: 0.783 n_sig: 26441 n_bkg: 1087427 n_observed: 1113868
#  significance: 25.254
#
#
# threshold: 0.690
# eff_sig: 0.506 eff_bkg: 0.802 n_sig: 25324 n_bkg: 988984 n_observed: 1014308
#  significance: 25.357
#
#
# threshold: 0.700
# eff_sig: 0.483 eff_bkg: 0.817 n_sig: 24172 n_bkg: 913304 n_observed: 937477
#  significance: 25.183
#
#
# threshold: 0.710
# eff_sig: 0.461 eff_bkg: 0.832 n_sig: 23060 n_bkg: 839267 n_observed: 862327
#  significance: 25.057
#
#
# threshold: 0.720
# eff_sig: 0.437 eff_bkg: 0.842 n_sig: 21860 n_bkg: 790381 n_observed: 812241
#  significance: 24.476
#
#
# threshold: 0.730
# eff_sig: 0.414 eff_bkg: 0.857 n_sig: 20680 n_bkg: 713433 n_observed: 734113
#  significance: 24.367
#
#
# threshold: 0.740
# eff_sig: 0.390 eff_bkg: 0.870 n_sig: 19509 n_bkg: 648127 n_observed: 667636
#  significance: 24.112
#
#
# threshold: 0.750
# eff_sig: 0.366 eff_bkg: 0.885 n_sig: 18313 n_bkg: 572970 n_observed: 591283
#  significance: 24.066
#
#
# threshold: 0.760
# eff_sig: 0.343 eff_bkg: 0.893 n_sig: 17134 n_bkg: 535578 n_observed: 552713
#  significance: 23.290
#
#
# threshold: 0.770
# eff_sig: 0.319 eff_bkg: 0.902 n_sig: 15937 n_bkg: 489977 n_observed: 505913
#  significance: 22.645
#
#
# threshold: 0.780
# eff_sig: 0.295 eff_bkg: 0.912 n_sig: 14769 n_bkg: 438255 n_observed: 453024
#  significance: 22.186
#
#
# threshold: 0.790
# eff_sig: 0.271 eff_bkg: 0.922 n_sig: 13571 n_bkg: 390414 n_observed: 403985
#  significance: 21.595
#
#
# threshold: 0.800
# eff_sig: 0.248 eff_bkg: 0.928 n_sig: 12422 n_bkg: 362277 n_observed: 374698
#  significance: 20.522
#
#
# threshold: 0.810
# eff_sig: 0.226 eff_bkg: 0.934 n_sig: 11277 n_bkg: 332050 n_observed: 343326
#  significance: 19.460
#
#
# threshold: 0.820
# eff_sig: 0.203 eff_bkg: 0.940 n_sig: 10156 n_bkg: 298389 n_observed: 308546
#  significance: 18.489
#
#
# threshold: 0.830
# eff_sig: 0.182 eff_bkg: 0.946 n_sig: 9105 n_bkg: 271819 n_observed: 280925
#  significance: 17.368
#
#
# threshold: 0.840
# eff_sig: 0.161 eff_bkg: 0.950 n_sig: 8052 n_bkg: 249056 n_observed: 257108
#  significance: 16.049
#
#
# threshold: 0.850
# eff_sig: 0.141 eff_bkg: 0.959 n_sig: 7040 n_bkg: 202708 n_observed: 209748
#  significance: 15.547
#
#
# threshold: 0.860
# eff_sig: 0.122 eff_bkg: 0.966 n_sig: 6098 n_bkg: 170466 n_observed: 176564
#  significance: 14.684
#
#
# threshold: 0.870
# eff_sig: 0.104 eff_bkg: 0.971 n_sig: 5202 n_bkg: 144343 n_observed: 149546
#  significance: 13.611
#
#
# threshold: 0.880
# eff_sig: 0.086 eff_bkg: 0.976 n_sig: 4292 n_bkg: 117997 n_observed: 122290
#  significance: 12.421
#
#
# threshold: 0.890
# eff_sig: 0.070 eff_bkg: 0.979 n_sig: 3493 n_bkg: 103742 n_observed: 107235
#  significance: 10.785
#
#
# threshold: 0.900
# eff_sig: 0.056 eff_bkg: 0.983 n_sig: 2786 n_bkg: 85307 n_observed: 88094
#  significance: 9.489
#
#
# threshold: 0.910
# eff_sig: 0.043 eff_bkg: 0.984 n_sig: 2162 n_bkg: 78740 n_observed: 80901
#  significance: 7.669
#
#
# threshold: 0.920
# eff_sig: 0.032 eff_bkg: 0.988 n_sig: 1597 n_bkg: 61574 n_observed: 63171
#  significance: 6.410
#
#
# threshold: 0.930
# eff_sig: 0.023 eff_bkg: 0.993 n_sig: 1149 n_bkg: 36198 n_observed: 37347
#  significance: 6.010
#
#
# threshold: 0.940
# eff_sig: 0.015 eff_bkg: 0.994 n_sig: 758 n_bkg: 29257 n_observed: 30015
#  significance: 4.414
#
#
# threshold: 0.950
# eff_sig: 0.009 eff_bkg: 0.997 n_sig: 461 n_bkg: 15972 n_observed: 16433
#  significance: 3.629
#
#
# threshold: 0.960
# eff_sig: 0.005 eff_bkg: 0.998 n_sig: 244 n_bkg: 8210 n_observed: 8454
#  significance: 2.683
#
#
# threshold: 0.970
# eff_sig: 0.002 eff_bkg: 0.999 n_sig: 107 n_bkg: 2761 n_observed: 2868
#  significance: 2.017
#
#
# threshold: 0.980
# eff_sig: 0.001 eff_bkg: 1.000 n_sig: 39 n_bkg: 2090 n_observed: 2129
#  significance: 0.856
#
#
# threshold: 0.990
# eff_sig: 0.000 eff_bkg: 1.000 n_sig: 6 n_bkg: 149 n_observed: 156
#  significance: 0.525

# %%
max_sig_threshold = thresholds[np.where(significance==max(significance))][0]
print(max(significance))
plt.figure(1)
plt.plot([max_sig_threshold, max_sig_threshold], [0, 1.05*max(significance)], 'k--')
plt.plot(thresholds, significance, label='maximum signal significance \n@ threshold = {:.3f}'.format(max_sig_threshold), color="red")
plt.xlabel('threshold')
plt.ylabel(r"$S/\sqrt{S+B}$")
plt.ylim([0.5*max(significance),1.1*max(significance)])
plt.title('signal significance')
plt.legend(loc="best")
plt.savefig("significance.pdf")
# Out:
# 26.43399788077029

# %%
from sklearn.metrics import roc_curve
y_pred_keras = model.predict_proba(x_test)[:,1]
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras,tpr_keras, label='(AUC = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(y_test, np.where(y_pred_keras > 0.5, 1, 0)).ravel()
accuracy    = (tp+tn)/len(y_test)
specificity = tn / (tn+fp)
sensitivity = tp / (tn+tp)
print("accuracy:", accuracy," specificity:", specificity, " sensitivity:", sensitivity);
# Out:
# accuracy: 0.5698050222193872  specificity: 0.45651038168166824  sensitivity: 0.4293897046476482
