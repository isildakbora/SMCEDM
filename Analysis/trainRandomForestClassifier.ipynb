# %%
# %config InlineBackend.figure_format = "retina"

# %%
import matplotlib.pyplot as plt
import math

import numpy as np
import pandas as pd

import ROOT, uproot

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import feature_selection
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
from sklearn import decomposition
from sklearn.linear_model import LogisticRegression
# Out:
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/bora/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# Welcome to JupyROOT 6.18/04

# %%
def upsample(sample, scale):
    '''
    This function takes the sample and concatantes the same sample n times.
    '''
    if scale > 0:
        sample = np.vstack([sample]*scale)
    else:
        sample = sample
    return sample

# %%
import keras
import tensorflow as tf
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 36} ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)
# Out:
# Using TensorFlow backend.
# /home/bora/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/bora/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2021-03-14 15:36:44.850618: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-03-14 15:36:44.857850: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2021-03-14 15:36:44.976644: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8a528d0 executing computations on platform CUDA. Devices:
# 2021-03-14 15:36:44.976699: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2021-03-14 15:36:44.984080: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2600000000 Hz
# 2021-03-14 15:36:44.989736: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x90da640 executing computations on platform Host. Devices:
# 2021-03-14 15:36:44.989777: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-03-14 15:36:44.992229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Quadro RTX 5000 major: 7 minor: 5 memoryClockRate(GHz): 1.815
# pciBusID: 0000:2d:00.0
# 2021-03-14 15:36:44.992832: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-14 15:36:44.995805: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-14 15:36:44.998399: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-14 15:36:44.999146: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-14 15:36:45.001949: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-14 15:36:45.003827: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-14 15:36:45.009863: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2021-03-14 15:36:45.012059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2021-03-14 15:36:45.012112: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-14 15:36:45.014041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-14 15:36:45.014053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2021-03-14 15:36:45.014059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2021-03-14 15:36:45.016040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13727 MB memory) -> physical GPU (device: 0, name: Quadro RTX 5000, pci bus id: 0000:2d:00.0, compute capability: 7.5)

# %%
input_branches = ['br_njets', 'br_nbjets', 'br_scalar_ht',
       'br_jet_pt_1', 'br_jet_pt_2', 'br_jet_pt_3', 'br_jet_pt_4', 'br_met',
       'br_met_phi', 'br_sphericity', 'br_aplanarity', 'br_fox_wolfram_1',
       'br_fox_wolfram_2', 'br_fox_wolfram_3', 'br_fox_wolfram_4']

df_signal = uproot.open("/mnt/harddisk4/scratch/ttbar_no_dtG_flat.root")["outtree"].pandas.df(input_branches)
df_dyjets = uproot.open("/mnt/harddisk4/scratch/dyjets_flat_30M.root")["outtree"].pandas.df(input_branches)
df_wjets  = uproot.open("/mnt/harddisk4/scratch/wjets_flat_60M.root")["outtree"].pandas.df(input_branches)
df_single_top  = uproot.open("/mnt/harddisk4/scratch/single_top_merged_flat.root")["outtree"].pandas.df(input_branches)
print(df_signal.keys())
#print("n_signal:", len(df_signal), "n_dyjets:", len(df_dyjets), "n_wjets:", len(df_wjets), "n_single_top", len(df_single_top))
# Out:
# Index(['br_njets', 'br_nbjets', 'br_scalar_ht', 'br_jet_pt_1', 'br_jet_pt_2',
#        'br_jet_pt_3', 'br_jet_pt_4', 'br_met', 'br_met_phi', 'br_sphericity',
#        'br_aplanarity', 'br_fox_wolfram_1', 'br_fox_wolfram_2',
#        'br_fox_wolfram_3', 'br_fox_wolfram_4'],
#       dtype='object')

# %%
x_signal = df_signal.values
y_signal = np.full(len(x_signal) , 1)
print("number of signal events:%d" % (len(x_signal)))

x_dyjets = df_dyjets.values
x_wjets  = df_wjets.values
x_single_top  = df_single_top.values

x_wjets  = upsample(x_wjets,  int((len(x_signal)/len(x_wjets))))
x_dyjets = upsample(x_dyjets, int((len(x_signal)/len(x_dyjets))))
idx_max = int(0.33*len(x_signal))
x_bkg    = np.concatenate((x_dyjets[0:idx_max], x_wjets[0:idx_max], x_single_top[0:idx_max]), axis=0)
#x_bkg    = np.concatenate((x_dyjets[0:idx_max], x_single_top[0:idx_max]), axis=0)

#x_bkg    = x_single_top[0:idx_max]
y_bkg    = np.full(len(x_bkg) , 0)
print(idx_max)
# Out:
# number of signal events:135342
# 44662

# %%
x_sig_train, x_sig_test, y_sig_train, y_sig_test = train_test_split(x_signal, y_signal, test_size=0.2, random_state=20)
x_bkg_train, x_bkg_test, y_bkg_train, y_bkg_test = train_test_split(x_bkg, y_bkg, test_size=0.5, random_state=20)

x_train = np.concatenate((x_sig_train, x_bkg_train), axis=0)
y_train = np.concatenate((y_sig_train, y_bkg_train), axis=0)

x_test = np.concatenate((x_sig_test, x_bkg_test), axis=0)
y_test = np.concatenate((y_sig_test, y_bkg_test), axis=0)
                                  
scaler  = preprocessing.StandardScaler().fit(np.concatenate((x_train, x_test), axis=0))
x_train = scaler.transform(x_train)
x_test  = scaler.transform(x_test)

# %%
print("training for", len(x_train), "events;", "testing for",  len(x_test), "events")
# Out:
# training for 175266 events; testing for 94062 events

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_jobs=64, n_estimators=50)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=64,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(model.predict(x_test), y_test)
# Out:
# 0.8154940358486955

# %%
x_signal_trans = scaler.transform(x_signal)

# %%
output_array1 = model.predict_proba(scaler.transform(x_sig_train))[:,1]
output_array2 = model.predict_proba(scaler.transform(x_bkg_train))[:,1]

output_array3 = model.predict_proba(scaler.transform(x_sig_test))[:,1]
output_array4 = model.predict_proba(scaler.transform(x_bkg_test))[:,1]

# %%
#print(model.evaluate(x_train, y_train))
#print(model.evaluate(x_test, y_test))
#print(model.evaluate(scaler.transform(x_signal), y_signal))
#print(model.evaluate(scaler.transform(x_bkg), y_bkg))

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots()
n_bins = 20

y, bins, patches = ax.hist(output_array2, bins=n_bins, density=True, color='blue', alpha=0.5, label='background (training)')
y, bins, patches = ax.hist(output_array4, bins=n_bins, density=True, color='blue', alpha=0.0)
bin_centers = [0.5*(bins[i]+bins[i+1]) for i in range(len(bins)-1)]
plt.scatter(bin_centers, y, marker='o', c='blue', s=40, alpha=1,  label='background (validation)')

y, bins, patches = ax.hist(output_array1, bins=n_bins, density=True, color='red', alpha=0.5, label='signal (training)')
y, bins, patches = ax.hist(output_array3, bins=n_bins, density=True, color='red', alpha=0.0)
bin_centers = [0.5*(bins[i]+bins[i+1]) for i in range(len(bins)-1)]
plt.scatter(0.5*(bins[1:] + bins[:-1]), y, marker='o', c='red', s=40, alpha=1, label='signal (validation)')

ax.set_xlabel('model output')
ax.set_ylabel('Probability density')
ax.set_title("RandomForest Classifier")
ax.legend()
#ax.set_yscale('log')

# %%
def get_signal_significance(xsec_sig, xsec_bkg, lumi, output_sig, output_bkg, thresholds):
    
    significance = []
    
    for threshold in thresholds:
        
        n_sig_expected = xsec_sig * lumi
        n_bkg_expected = xsec_bkg * lumi
        
        n_sig_pred_correct = len(output_sig[output_sig>threshold])
        n_sig_pred_wrong   = len(output_sig[output_sig<threshold])
        n_bkg_pred_correct = len(output_bkg[output_bkg<threshold])
        n_bkg_pred_wrong   = len(output_bkg[output_bkg>threshold])
        
        eff_sig = n_sig_pred_correct/len(output_sig)
        eff_bkg = n_bkg_pred_correct/len(output_bkg)
        
        n_sig = n_sig_expected * eff_sig
        n_bkg = n_bkg_expected * (1-eff_bkg)
        
        n_observed = n_sig + n_bkg
        
        if n_bkg > 0:
            sig = math.sqrt(2*n_observed*math.log(1+n_sig/n_bkg)-2*n_sig)
            #sig = n_sig/math.sqrt(n_sig+n_bkg)
        else:
            sig = 0
        
        print("threshold:", "{:.3f}".format(threshold), "\n"
              "eff_sig:", "{:.3f}".format(eff_sig),
              "eff_bkg:", "{:.3f}".format(eff_bkg),
              "n_sig:", "{:.0f}".format(n_sig), 
              "n_bkg:", "{:.0f}".format(n_bkg),
              "n_observed:", "{:.0f}".format(n_observed), "\n",
              "significance:", "{:.3f}".format(sig), "\n\n")
        
        significance.append(sig)    
        
    return thresholds, np.array(significance)

# %%
thresholds , significance = get_signal_significance(1, 10, 50000, output_array3, 
                                                    output_array4, np.arange(0.1, 1-1e-3, 1e-2))
# Out:
# threshold: 0.100
# eff_sig: 1.000 eff_bkg: 0.670 n_sig: 49991 n_bkg: 165137 n_observed: 215127
#  significance: 117.484
#
#
# threshold: 0.110
# eff_sig: 1.000 eff_bkg: 0.670 n_sig: 49991 n_bkg: 164928 n_observed: 214918
#  significance: 117.552
#
#
# threshold: 0.120
# eff_sig: 1.000 eff_bkg: 0.670 n_sig: 49983 n_bkg: 164928 n_observed: 214911
#  significance: 117.535
#
#
# threshold: 0.130
# eff_sig: 1.000 eff_bkg: 0.671 n_sig: 49983 n_bkg: 164689 n_observed: 214672
#  significance: 117.613
#
#
# threshold: 0.140
# eff_sig: 1.000 eff_bkg: 0.671 n_sig: 49983 n_bkg: 164689 n_observed: 214672
#  significance: 117.613
#
#
# threshold: 0.150
# eff_sig: 1.000 eff_bkg: 0.672 n_sig: 49978 n_bkg: 164122 n_observed: 214099
#  significance: 117.787
#
#
# threshold: 0.160
# eff_sig: 1.000 eff_bkg: 0.672 n_sig: 49978 n_bkg: 164122 n_observed: 214099
#  significance: 117.787
#
#
# threshold: 0.170
# eff_sig: 0.999 eff_bkg: 0.673 n_sig: 49974 n_bkg: 163495 n_observed: 213469
#  significance: 117.985
#
#
# threshold: 0.180
# eff_sig: 0.999 eff_bkg: 0.673 n_sig: 49974 n_bkg: 163495 n_observed: 213469
#  significance: 117.985
#
#
# threshold: 0.190
# eff_sig: 0.999 eff_bkg: 0.675 n_sig: 49967 n_bkg: 162748 n_observed: 212715
#  significance: 118.215
#
#
# threshold: 0.200
# eff_sig: 0.999 eff_bkg: 0.675 n_sig: 49967 n_bkg: 162748 n_observed: 212715
#  significance: 118.215
#
#
# threshold: 0.210
# eff_sig: 0.999 eff_bkg: 0.677 n_sig: 49948 n_bkg: 161711 n_observed: 211659
#  significance: 118.519
#
#
# threshold: 0.220
# eff_sig: 0.999 eff_bkg: 0.677 n_sig: 49948 n_bkg: 161711 n_observed: 211659
#  significance: 118.519
#
#
# threshold: 0.230
# eff_sig: 0.999 eff_bkg: 0.679 n_sig: 49937 n_bkg: 160614 n_observed: 210551
#  significance: 118.863
#
#
# threshold: 0.240
# eff_sig: 0.999 eff_bkg: 0.679 n_sig: 49937 n_bkg: 160614 n_observed: 210551
#  significance: 118.863
#
#
# threshold: 0.250
# eff_sig: 0.998 eff_bkg: 0.682 n_sig: 49909 n_bkg: 159166 n_observed: 209075
#  significance: 119.293
#
#
# threshold: 0.260
# eff_sig: 0.998 eff_bkg: 0.682 n_sig: 49909 n_bkg: 159166 n_observed: 209075
#  significance: 119.293
#
#
# threshold: 0.270
# eff_sig: 0.998 eff_bkg: 0.685 n_sig: 49889 n_bkg: 157733 n_observed: 207622
#  significance: 119.739
#
#
# threshold: 0.280
# eff_sig: 0.998 eff_bkg: 0.685 n_sig: 49889 n_bkg: 157733 n_observed: 207622
#  significance: 119.739
#
#
# threshold: 0.290
# eff_sig: 0.997 eff_bkg: 0.688 n_sig: 49849 n_bkg: 156151 n_observed: 205999
#  significance: 120.198
#
#
# threshold: 0.300
# eff_sig: 0.997 eff_bkg: 0.688 n_sig: 49849 n_bkg: 156151 n_observed: 205999
#  significance: 120.198
#
#
# threshold: 0.310
# eff_sig: 0.996 eff_bkg: 0.692 n_sig: 49801 n_bkg: 154128 n_observed: 203929
#  significance: 120.803
#
#
# threshold: 0.320
# eff_sig: 0.996 eff_bkg: 0.692 n_sig: 49801 n_bkg: 154128 n_observed: 203929
#  significance: 120.803
#
#
# threshold: 0.330
# eff_sig: 0.995 eff_bkg: 0.696 n_sig: 49758 n_bkg: 151956 n_observed: 201714
#  significance: 121.486
#
#
# threshold: 0.340
# eff_sig: 0.995 eff_bkg: 0.696 n_sig: 49758 n_bkg: 151956 n_observed: 201714
#  significance: 121.486
#
#
# threshold: 0.350
# eff_sig: 0.994 eff_bkg: 0.701 n_sig: 49692 n_bkg: 149747 n_observed: 199439
#  significance: 122.142
#
#
# threshold: 0.360
# eff_sig: 0.994 eff_bkg: 0.701 n_sig: 49692 n_bkg: 149747 n_observed: 199439
#  significance: 122.142
#
#
# threshold: 0.370
# eff_sig: 0.992 eff_bkg: 0.706 n_sig: 49612 n_bkg: 147045 n_observed: 196657
#  significance: 122.968
#
#
# threshold: 0.380
# eff_sig: 0.992 eff_bkg: 0.706 n_sig: 49612 n_bkg: 147045 n_observed: 196657
#  significance: 122.968
#
#
# threshold: 0.390
# eff_sig: 0.991 eff_bkg: 0.711 n_sig: 49538 n_bkg: 144321 n_observed: 193859
#  significance: 123.840
#
#
# threshold: 0.400
# eff_sig: 0.991 eff_bkg: 0.711 n_sig: 49538 n_bkg: 144321 n_observed: 193859
#  significance: 123.840
#
#
# threshold: 0.410
# eff_sig: 0.988 eff_bkg: 0.717 n_sig: 49424 n_bkg: 141298 n_observed: 190722
#  significance: 124.757
#
#
# threshold: 0.420
# eff_sig: 0.988 eff_bkg: 0.717 n_sig: 49424 n_bkg: 141298 n_observed: 190722
#  significance: 124.757
#
#
# threshold: 0.430
# eff_sig: 0.986 eff_bkg: 0.724 n_sig: 49293 n_bkg: 138171 n_observed: 187464
#  significance: 125.707
#
#
# threshold: 0.440
# eff_sig: 0.986 eff_bkg: 0.724 n_sig: 49293 n_bkg: 138171 n_observed: 187464
#  significance: 125.707
#
#
# threshold: 0.450
# eff_sig: 0.983 eff_bkg: 0.730 n_sig: 49160 n_bkg: 134820 n_observed: 183980
#  significance: 126.781
#
#
# threshold: 0.460
# eff_sig: 0.983 eff_bkg: 0.730 n_sig: 49160 n_bkg: 134820 n_observed: 183980
#  significance: 126.781
#
#
# threshold: 0.470
# eff_sig: 0.980 eff_bkg: 0.737 n_sig: 48984 n_bkg: 131275 n_observed: 180259
#  significance: 127.877
#
#
# threshold: 0.480
# eff_sig: 0.980 eff_bkg: 0.737 n_sig: 48984 n_bkg: 131275 n_observed: 180259
#  significance: 127.877
#
#
# threshold: 0.490
# eff_sig: 0.976 eff_bkg: 0.745 n_sig: 48786 n_bkg: 127648 n_observed: 176434
#  significance: 129.001
#
#
# threshold: 0.500
# eff_sig: 0.976 eff_bkg: 0.745 n_sig: 48786 n_bkg: 127648 n_observed: 176434
#  significance: 129.001
#
#
# threshold: 0.510
# eff_sig: 0.971 eff_bkg: 0.753 n_sig: 48563 n_bkg: 123722 n_observed: 172285
#  significance: 130.252
#
#
# threshold: 0.520
# eff_sig: 0.971 eff_bkg: 0.753 n_sig: 48563 n_bkg: 123722 n_observed: 172285
#  significance: 130.252
#
#
# threshold: 0.530
# eff_sig: 0.965 eff_bkg: 0.761 n_sig: 48262 n_bkg: 119587 n_observed: 167849
#  significance: 131.470
#
#
# threshold: 0.540
# eff_sig: 0.965 eff_bkg: 0.761 n_sig: 48262 n_bkg: 119587 n_observed: 167849
#  significance: 131.470
#
#
# threshold: 0.550
# eff_sig: 0.959 eff_bkg: 0.769 n_sig: 47926 n_bkg: 115408 n_observed: 163333
#  significance: 132.693
#
#
# threshold: 0.560
# eff_sig: 0.959 eff_bkg: 0.769 n_sig: 47926 n_bkg: 115408 n_observed: 163333
#  significance: 132.693
#
#
# threshold: 0.570
# eff_sig: 0.951 eff_bkg: 0.778 n_sig: 47562 n_bkg: 110967 n_observed: 158529
#  significance: 134.059
#
#
# threshold: 0.580
# eff_sig: 0.951 eff_bkg: 0.778 n_sig: 47562 n_bkg: 110967 n_observed: 158529
#  significance: 134.059
#
#
# threshold: 0.590
# eff_sig: 0.942 eff_bkg: 0.787 n_sig: 47093 n_bkg: 106354 n_observed: 153447
#  significance: 135.335
#
#
# threshold: 0.600
# eff_sig: 0.942 eff_bkg: 0.787 n_sig: 47093 n_bkg: 106354 n_observed: 153447
#  significance: 135.335
#
#
# threshold: 0.610
# eff_sig: 0.931 eff_bkg: 0.797 n_sig: 46553 n_bkg: 101346 n_observed: 147900
#  significance: 136.757
#
#
# threshold: 0.620
# eff_sig: 0.931 eff_bkg: 0.797 n_sig: 46553 n_bkg: 101346 n_observed: 147900
#  significance: 136.757
#
#
# threshold: 0.630
# eff_sig: 0.920 eff_bkg: 0.808 n_sig: 45981 n_bkg: 95928 n_observed: 141909
#  significance: 138.483
#
#
# threshold: 0.640
# eff_sig: 0.920 eff_bkg: 0.808 n_sig: 45981 n_bkg: 95928 n_observed: 141909
#  significance: 138.483
#
#
# threshold: 0.650
# eff_sig: 0.906 eff_bkg: 0.818 n_sig: 45299 n_bkg: 90942 n_observed: 136241
#  significance: 139.786
#
#
# threshold: 0.660
# eff_sig: 0.906 eff_bkg: 0.818 n_sig: 45299 n_bkg: 90942 n_observed: 136241
#  significance: 139.786
#
#
# threshold: 0.670
# eff_sig: 0.889 eff_bkg: 0.829 n_sig: 44451 n_bkg: 85748 n_observed: 130199
#  significance: 140.903
#
#
# threshold: 0.680
# eff_sig: 0.889 eff_bkg: 0.829 n_sig: 44451 n_bkg: 85748 n_observed: 130199
#  significance: 140.903
#
#
# threshold: 0.690
# eff_sig: 0.871 eff_bkg: 0.840 n_sig: 43563 n_bkg: 79941 n_observed: 123504
#  significance: 142.543
#
#
# threshold: 0.700
# eff_sig: 0.871 eff_bkg: 0.840 n_sig: 43563 n_bkg: 79941 n_observed: 123504
#  significance: 142.543
#
#
# threshold: 0.710
# eff_sig: 0.848 eff_bkg: 0.852 n_sig: 42406 n_bkg: 74194 n_observed: 116601
#  significance: 143.562
#
#
# threshold: 0.720
# eff_sig: 0.848 eff_bkg: 0.852 n_sig: 42406 n_bkg: 74194 n_observed: 116601
#  significance: 143.562
#
#
# threshold: 0.730
# eff_sig: 0.824 eff_bkg: 0.863 n_sig: 41184 n_bkg: 68567 n_observed: 109751
#  significance: 144.520
#
#
# threshold: 0.740
# eff_sig: 0.824 eff_bkg: 0.863 n_sig: 41184 n_bkg: 68567 n_observed: 109751
#  significance: 144.520
#
#
# threshold: 0.750
# eff_sig: 0.797 eff_bkg: 0.875 n_sig: 39856 n_bkg: 62454 n_observed: 102310
#  significance: 145.888
#
#
# threshold: 0.760
# eff_sig: 0.797 eff_bkg: 0.875 n_sig: 39856 n_bkg: 62454 n_observed: 102310
#  significance: 145.888
#
#
# threshold: 0.770
# eff_sig: 0.765 eff_bkg: 0.887 n_sig: 38267 n_bkg: 56700 n_observed: 94967
#  significance: 146.375
#
#
# threshold: 0.780
# eff_sig: 0.765 eff_bkg: 0.887 n_sig: 38267 n_bkg: 56700 n_observed: 94967
#  significance: 146.375
#
#
# threshold: 0.790
# eff_sig: 0.730 eff_bkg: 0.899 n_sig: 36496 n_bkg: 50520 n_observed: 87016
#  significance: 147.080
#
#
# threshold: 0.800
# eff_sig: 0.730 eff_bkg: 0.899 n_sig: 36496 n_bkg: 50520 n_observed: 87016
#  significance: 147.080
#
#
# threshold: 0.810
# eff_sig: 0.688 eff_bkg: 0.911 n_sig: 34381 n_bkg: 44393 n_observed: 78773
#  significance: 146.941
#
#
# threshold: 0.820
# eff_sig: 0.688 eff_bkg: 0.911 n_sig: 34381 n_bkg: 44393 n_observed: 78773
#  significance: 146.941
#
#
# threshold: 0.830
# eff_sig: 0.640 eff_bkg: 0.923 n_sig: 32005 n_bkg: 38310 n_observed: 70315
#  significance: 146.258
#
#
# threshold: 0.840
# eff_sig: 0.640 eff_bkg: 0.923 n_sig: 32005 n_bkg: 38310 n_observed: 70315
#  significance: 146.258
#
#
# threshold: 0.850
# eff_sig: 0.586 eff_bkg: 0.935 n_sig: 29314 n_bkg: 32615 n_observed: 61929
#  significance: 144.193
#
#
# threshold: 0.860
# eff_sig: 0.586 eff_bkg: 0.935 n_sig: 29314 n_bkg: 32615 n_observed: 61929
#  significance: 144.193
#
#
# threshold: 0.870
# eff_sig: 0.528 eff_bkg: 0.946 n_sig: 26381 n_bkg: 26876 n_observed: 53257
#  significance: 141.711
#
#
# threshold: 0.880
# eff_sig: 0.528 eff_bkg: 0.946 n_sig: 26381 n_bkg: 26876 n_observed: 53257
#  significance: 141.711
#
#
# threshold: 0.890
# eff_sig: 0.459 eff_bkg: 0.957 n_sig: 22945 n_bkg: 21472 n_observed: 44417
#  significance: 136.678
#
#
# threshold: 0.900
# eff_sig: 0.459 eff_bkg: 0.957 n_sig: 22945 n_bkg: 21472 n_observed: 44417
#  significance: 136.678
#
#
# threshold: 0.910
# eff_sig: 0.385 eff_bkg: 0.968 n_sig: 19232 n_bkg: 16188 n_observed: 35421
#  significance: 130.401
#
#
# threshold: 0.920
# eff_sig: 0.385 eff_bkg: 0.968 n_sig: 19232 n_bkg: 16188 n_observed: 35421
#  significance: 130.401
#
#
# threshold: 0.930
# eff_sig: 0.304 eff_bkg: 0.977 n_sig: 15187 n_bkg: 11456 n_observed: 26644
#  significance: 120.830
#
#
# threshold: 0.940
# eff_sig: 0.304 eff_bkg: 0.977 n_sig: 15187 n_bkg: 11456 n_observed: 26644
#  significance: 120.830
#
#
# threshold: 0.950
# eff_sig: 0.218 eff_bkg: 0.985 n_sig: 10900 n_bkg: 7463 n_observed: 18363
#  significance: 106.145
#
#
# threshold: 0.960
# eff_sig: 0.218 eff_bkg: 0.985 n_sig: 10900 n_bkg: 7463 n_observed: 18363
#  significance: 106.145
#
#
# threshold: 0.970
# eff_sig: 0.129 eff_bkg: 0.993 n_sig: 6467 n_bkg: 3642 n_observed: 10109
#  significance: 87.782
# threshold: 0.980
# eff_sig: 0.129 eff_bkg: 0.993 n_sig: 6467 n_bkg: 3642 n_observed: 10109
#  significance: 87.782
#
#
# threshold: 0.990
# eff_sig: 0.052 eff_bkg: 0.998 n_sig: 2595 n_bkg: 1187 n_observed: 3782
#  significance: 59.804

# %%
max_sig_threshold = thresholds[np.where(significance==max(significance))][0]
print(max(significance))
plt.figure(1)
plt.plot([max_sig_threshold, max_sig_threshold], [0, 1.05*max(significance)], 'k--')
plt.plot(thresholds, significance, label='maximum signal significance \n@ threshold = {:.3f}'.format(max_sig_threshold), color="red")
plt.xlabel('threshold')
plt.ylabel(r"$S/\sqrt{S+B}$")
plt.ylim([0,1.1*max(significance)])
plt.title('signal significance')
plt.legend(loc="best")
plt.savefig("significance.pdf")
# Out:
# 147.08047994430876

# %%
from sklearn.metrics import roc_curve
y_pred_keras = model.predict_proba(x_test)[:,1]
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras,tpr_keras, label='(AUC = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(y_test, np.where(y_pred_keras > 0.5, 1, 0)).ravel()
accuracy    = (tp+tn)/len(y_test)
specificity = tn / (tn+fp)
sensitivity = tp / (tn+tp)
print("accuracy:", accuracy," specificity:", specificity, " sensitivity:", sensitivity);
# Out:
# accuracy: 0.8154940358486955  specificity: 0.7525562372188139  sensitivity: 0.3427457728760087
